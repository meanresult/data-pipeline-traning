# %% [markdown]
# Snowflake Python Client 설정하기
#
# 로그인을 위한 credential을 Colab Secrets에 설정하고 읽어들이기
# snowflake-connector-python 파이썬 모듈 설치

# %%
from dotenv import load_dotenv
import snowflake.connector
import os

def return_snowflake_conn():

    load_dotenv(override=True)

    conn = snowflake.connector.connect(
        user=os.getenv("SNOWFLAKE_USER"),
        password=os.getenv("SNOWFLAKE_PASSWORD"),
        account=os.getenv("SNOWFLAKE_ACCOUNT")
    )
    return conn.cursor()

print("Connection successful!")
print(os.getenv("SNOWFLAKE_ACCOUNT"))
# Out:
# Connection successful!
# mpqflwu-wp69976

# %% [markdown]
# # 첫 번째 버전 : ETL 함수 정의

# %%
import requests

def extract(url):
    f=requests.get(url)
    return f.text

# %%
def transform(text):
    lines = text.strip().split("\n")
    records = []
    for l in lines:
        (country, capital) = l.split(",")
        records.append([country, capital])
    return records

# %%
def load(cur, records):
    target_table = "dev.raw_data.country_capital"
    cur.execute(f"""
        CREATE TABLE IF NOT EXISTS {target_table} (
            country varchar primary key,
            capital varchar
        )
    """)
    for r in records:
        country = r[0].replace("'", "''")
        capital = r[1].replace("'", "''")
        sql = f"insert into {target_table} (country, capital) values ('{country}', '{capital}')"
        print(country, "-", capital, "-", sql)
        cur.execute(sql)

# %%
link = "https://s3-geospatial.s3.us-west-2.amazonaws.com/country_capital.csv"

data = extract(link)

# %%
data
# Out:
# "country,capital\nAbkhazia,Sukhumi\nAfghanistan,Kabul\nAkrotiri and Dhekelia,Episkopi Cantonment\nAlbania,Tirana\nAlgeria,Algiers\nAmerican Samoa,Pago Pago\nAndorra,Andorra la Vella\nAngola,Luanda\nAnguilla,The Valley\nAntigua and Barbuda,St. John's\nArgentina,Buenos Aires\nArmenia,Yerevan\nAruba,Oranjestad\nAscension Island,Georgetown\nAustralia,Canberra\nAustria,Vienna\nAzerbaijan,Baku\nBahamas,Nassau\nBahrain,Manama\nBangladesh,Dhaka\nBarbados,Bridgetown\nBelarus,Minsk\nBelgium,Brussels\nBelize,Belmopan\nBenin,Porto-Novo\nBermuda,Hamilton\nBhutan,Thimphu\nBolivia,La Paz\nBosnia and Herzegovina,Sarajevo\nBotswana,Gaborone\nBrazil,Brasâ\x88\x9aâ\x89\xa0lia\nBritish Virgin Islands,Road Town\nBrunei,Bandar Seri Begawan\nBulgaria,Sofia\nBurkina Faso,Ouagadougou\nBurundi,Bujumbura\nCambodia,Phnom Penh\nCameroon,Yaoundâ\x88\x9aÂ©\nCanada,Ottawa\nCape Verde,Praia\nCayman Islands,George Town\nCentral African Republic,Bangui\nChad,N'Djamena\nChile,Santiago\nChina,Beijing\nChristmas Island,Flying Fish Cove\nCocos (Keeling) Islands,West Island\nColombia,Bogotâ\x88\x9aÂ°\nComoros,Moroni\nCook Islands,Avarua\nCosta Rica,San Josâ\x88\x9aÂ©\nCroatia,Zagreb\nCuba,Havana\nCuraâ\x88\x9aÃ\x9fao,Willemstad\nCyprus,Nicosia\nCzech Republic,Prague\nCâ\x88\x9aÂ¥te d'Ivoire,Yamoussoukro\nDemocratic Republic of the Congo,Kinshasa\nDenmark,Copenhagen\nDjibouti,Djibouti\nDominica,Roseau\nDominican Republic,Santo Domingo\nEast Timor (Timor-Leste),Dili\nEaster Island,Hanga Roa\nEcuador,Quito\nEgypt,Cairo\nEl Salvador,San Salvador\nEquatorial Guinea,Malabo\nEritrea,Asmara\nEstonia,Tallinn\nEthiopia,Addis Ababa\nFalkland Islands,Stanley\nFaroe Islands,Tâ\x88\x9aâ\x89¥rshavn\nFederated States of Micronesia,Palikir\nFiji,Suva\nFinland,Helsinki\nFrance,Paris\nFrench Guiana,Cayenne\nFrench Polynesia,Papeete\nGabon,Libreville\nGambia,Banjul\nGeorgia,Tbilisi\nGermany,Berlin\nGhana,Accra\nGibraltar,Gibraltar\nGreece,Athens\nGreenland,Nuuk\nGrenada,St. George's\nGuam,Hagâ\x88\x9aâ\x80¢tâ\x88\x9aÂ±a\nGuatemala,Guatemala City\nGuernsey,St. Peter Port\nGuinea,Conakry\nGuinea-Bissau,Bissau\nGuyana,Georgetown\nHaiti,Port-au-Prince\nHonduras,Tegucigalpa\nHungary,Budapest\nIceland,Reykjavâ\x88\x9aâ\x89\xa0k\nIndia,New Delhi\nIndonesia,Jakarta\nIran,Tehran\nIraq,Baghdad\nIreland,Dublin\nIsle of Man,Douglas\nIsrael,Jerusalem\nItaly,Rome\nJamaica,Kingston\nJapan,Tokyo\nJersey,St. Helier\nJordan,Amman\nKazakhstan,Astana\nKenya,Nairobi\nKiribati,Tarawa\nKosovo,Pristina\nKuwait,Kuwait City\nKyrgyzstan,Bishkek\nLaos,Vientiane\nLatvia,Riga\nLebanon,Beirut\nLesotho,Maseru\nLiberia,Monrovia\nLibya,Tripoli\nLiechtenstein,Vaduz\nLithuania,Vilnius\nLuxembourg,Luxembourg\nMacedonia,Skopje\nMadagascar,Antananarivo\nMalawi,Lilongwe\nMalaysia,Kuala Lumpur\nMaldives,Malâ\x88\x9aÂ©\nMali,Bamako\nMalta,Valletta\nMarshall Islands,Majuro\nMauritania,Nouakchott\nMauritius,Port Louis\nMexico,Mexico City\nMoldova,Chisinau\nMonaco,Monaco\nMongolia,Ulaanbaatar\nMontenegro,Podgorica\nMontserrat,Plymouth\nMorocco,Rabat\nMozambique,Maputo\nMyanmar,Naypyidaw\nNagorno-Karabakh Republic,Stepanakert\nNamibia,Windhoek\nNauru,Yaren\nNepal,Kathmandu\nNetherlands,Amsterdam\nNew Caledonia,Noumâ\x88\x9aÂ©a\nNew Zealand,Wellington\nNicaragua,Managua\nNiger,Niamey\nNigeria,Abuja\nNiue,Alofi\nNorfolk Island,Kingston\nNorth Korea,Pyongyang\nNorthern Cyprus,Nicosia\nUnited Kingdom Northern Ireland,Belfast\nNorthern Mariana Islands,Saipan\nNorway,Oslo\nOman,Muscat\nPakistan,Islamabad\nPalau,Ngerulmud\nPalestine,Jerusalem\nPanama,Panama City\nPapua New Guinea,Port Moresby\nParaguay,Asunciâ\x88\x9aâ\x89¥n\nPeru,Lima\nPhilippines,Manila\nPitcairn Islands,Adamstown\nPoland,Warsaw\nPortugal,Lisbon\nPuerto Rico,San Juan\nQatar,Doha\nRepublic of China (Taiwan),Taipei\nRepublic of the Congo,Brazzaville\nRomania,Bucharest\nRussia,Moscow\nRwanda,Kigali\nSaint Barthâ\x88\x9aÂ©lemy,Gustavia\nSaint Helena,Jamestown\nSaint Kitts and Nevis,Basseterre\nSaint Lucia,Castries\nSaint Martin,Marigot\nSaint Pierre and Miquelon,St. Pierre ...

# %%
len(data)
# Out:
# 5069

# %%
lines = transform(data)

# %%
len(lines)
# Out:
# 248

# %%
lines[0:10]
# Out:
# [['country', 'capital'],
#  ['Abkhazia', 'Sukhumi'],
#  ['Afghanistan', 'Kabul'],
#  ['Akrotiri and Dhekelia', 'Episkopi Cantonment'],
#  ['Albania', 'Tirana'],
#  ['Algeria', 'Algiers'],
#  ['American Samoa', 'Pago Pago'],
#  ['Andorra', 'Andorra la Vella'],
#  ['Angola', 'Luanda'],
#  ['Anguilla', 'The Valley']]

# %%
cur = return_snowflake_conn()
load(cur, lines)
# Out:
# country - capital - insert into dev.raw_data.country_capital (country, capital) values ('country', 'capital')
# Abkhazia - Sukhumi - insert into dev.raw_data.country_capital (country, capital) values ('Abkhazia', 'Sukhumi')
# Afghanistan - Kabul - insert into dev.raw_data.country_capital (country, capital) values ('Afghanistan', 'Kabul')
# Akrotiri and Dhekelia - Episkopi Cantonment - insert into dev.raw_data.country_capital (country, capital) values ('Akrotiri and Dhekelia', 'Episkopi Cantonment')
# Albania - Tirana - insert into dev.raw_data.country_capital (country, capital) values ('Albania', 'Tirana')
# Algeria - Algiers - insert into dev.raw_data.country_capital (country, capital) values ('Algeria', 'Algiers')
# American Samoa - Pago Pago - insert into dev.raw_data.country_capital (country, capital) values ('American Samoa', 'Pago Pago')
# Andorra - Andorra la Vella - insert into dev.raw_data.country_capital (country, capital) values ('Andorra', 'Andorra la Vella')
# Angola - Luanda - insert into dev.raw_data.country_capital (country, capital) values ('Angola', 'Luanda')
# Anguilla - The Valley - insert into dev.raw_data.country_capital (country, capital) values ('Anguilla', 'The Valley')
# Antigua and Barbuda - St. John''s - insert into dev.raw_data.country_capital (country, capital) values ('Antigua and Barbuda', 'St. John''s')
# Argentina - Buenos Aires - insert into dev.raw_data.country_capital (country, capital) values ('Argentina', 'Buenos Aires')
# Armenia - Yerevan - insert into dev.raw_data.country_capital (country, capital) values ('Armenia', 'Yerevan')
# Aruba - Oranjestad - insert into dev.raw_data.country_capital (country, capital) values ('Aruba', 'Oranjestad')
# Ascension Island - Georgetown - insert into dev.raw_data.country_capital (country, capital) values ('Ascension Island', 'Georgetown')
# Australia - Canberra - insert into dev.raw_data.country_capital (country, capital) values ('Australia', 'Canberra')
# Austria - Vienna - insert into dev.raw_data.country_capital (country, capital) values ('Austria', 'Vienna')
# Azerbaijan - Baku - insert into dev.raw_data.country_capital (country, capital) values ('Azerbaijan', 'Baku')
# Bahamas - Nassau - insert into dev.raw_data.country_capital (country, capital) values ('Bahamas', 'Nassau')
# Bahrain - Manama - insert into dev.raw_data.country_capital (country, capital) values ('Bahrain', 'Manama')
# Bangladesh - Dhaka - insert into dev.raw_data.country_capital (country, capital) values ('Bangladesh', 'Dhaka')
# Barbados - Bridgetown - insert into dev.raw_data.country_capital (country, capital) values ('Barbados', 'Bridgetown')
# Belarus - Minsk - insert into dev.raw_data.country_capital (country, capital) values ('Belarus', 'Minsk')
# Belgium - Brussels - insert into dev.raw_data.country_capital (country, capital) values ('Belgium', 'Brussels')
# Belize - Belmopan - insert into dev.raw_data.country_capital (country, capital) values ('Belize', 'Belmopan')
# Benin - Porto-Novo - insert into dev.raw_data.country_capital (country, capital) values ('Benin', 'Porto-Novo')
# Bermuda - Hamilton - insert into dev.raw_data.country_capital (country, capital) values ('Bermuda', 'Hamilton')
# Bhutan - Thimphu - insert into dev.raw_data.country_capital (country, capital) values ('Bhutan', 'Thimphu')
# Bolivia - La Paz - insert into dev.raw_data.country_capital (country, capital) values ('Bolivia', 'La Paz')
# Bosnia and Herzegovina - Sarajevo - insert into dev.raw_data.country_capital (country, capital) values ('Bosnia and Herzegovina', 'Sarajevo')
# Botswana - Gaborone - insert into dev.raw_data.country_capital (country, capital) values ('Botswana', 'Gaborone')
# Brazil - Brasââ lia - insert into dev.raw_data.country_capital (country, capital) values ('Brazil', 'Brasââ lia')
# British Virgin Islands - Road Town - insert into dev.raw_data.country_capital (country, capital) values ('British Virgin Islands', 'Road Town')
# Brunei - Bandar Seri Begawan - insert into dev.raw_data.country_capital (country, capital) values ('Brunei', 'Bandar Seri Begawan')
# Bulgaria - Sofia - insert into dev.raw_data.country_capital (country, capital) values ('Bulgaria', 'Sofia')
# Burkina Faso - Ouagadougou - insert into dev.raw_data.country_capital (country, capital) values ('Burkina Faso', 'Ouagadougou')
# Burundi - Bujumbura - insert into dev.raw_data.country_capital (country, capital) values ('Burundi', 'Bujumbura')
# Cambodia - Phnom Penh - insert into dev.raw_data.country_capital (country, capital) values ('Cambodia', 'Phnom Penh')
# Cameroon - YaoundâÂ© - insert into dev.raw_data.country_capital (country, capital) values ('Cameroon', 'YaoundâÂ©')
# Canada - Ottawa - insert into dev.raw_data.country_capital (country, capital) values ('Canada', 'Ottawa')
# Cape Verde - Praia - insert into dev.raw_data.country_capital (country, capital) values ('Cape Verde', 'Praia')
# Cayman Islands - George Town - insert into dev.raw_data.country_capital (country, capital) values ('Cayman Islands', 'George Town')
# Central African Republic - Bangui - insert into dev.raw_data.country_capital (country, capital) values ('Central African Republic', 'Bangui')
# Chad - N''Djamena - insert into dev.raw_data.country_capital (country, capital) values ('Chad', 'N''Djamena')
# Chile - Santiago - insert into dev.raw_data.country_capital (country, capital) values ('Chile', 'Santiago')
# China - Beijing - insert into dev.raw_data.country_capital (country, capital) values ('China', 'Beijing')
# Christmas Island - Flying Fish Cove - insert into dev.raw_data.country_capital (country, capital) values ('Christmas Island', 'Flying Fish Cove')
# Cocos (Keeling) Islands - West Island - insert into dev.raw_data.country_capital (country, capital) values ('Cocos (Keeling) Islands', 'West Island')
# Colombia - BogotâÂ° - insert into dev.raw_data.country_capital (country, capital) values ('Colombia', 'BogotâÂ°')
# Comoros - Moroni - insert into dev.raw_data.country_capital (country, capital) values ('Comoros', 'Moroni')
# Cook Islands - Avarua - insert into dev.raw_data.country_capital (country, capital) values ('Cook Islands', 'Avarua')
# Costa Rica - San JosâÂ© - insert into dev.raw_data.country_capital (country, capital) values ('Costa Rica', 'San JosâÂ©')
# Croatia - Zagreb - insert into dev.raw_data.country_capital (country, capital) values ('Croatia', 'Zagreb')
# Cuba - Havana - insert into dev.raw_data.country_capital (country, capital) values ('Cuba', 'Havana')
# CuraâÃao - Willemstad - insert into dev.raw_data.country_capital (country, capital) values ('CuraâÃao', 'Willemstad')
# Cyprus - Nicosia - insert into dev.raw_data.country_capital (country, capital) values ('Cyprus', 'Nicosia')
# Czech Republic - Prague - insert into dev.raw_data.country_capital (country, capital) values ('Czech Republic', 'Prague')
# CâÂ¥te d''Ivoire - Yamoussoukro - insert into dev.raw_data.country_capital (country, capital) values ('CâÂ¥te d''Ivoire', 'Yamoussoukro')
# Democratic Republic of the Congo - Kinshasa - insert into dev.raw_data.country_capital (country, capital) values ('Democratic Republic of the Congo', 'Kinshasa')
# Denmark - Copenhagen - insert into dev.raw_data.country_capital (country, capital) values ('Denmark', 'Copenhagen')
# Djibouti - Djibouti - insert into dev.raw_data.country_capital (country, capital) values ('Djibouti', 'Djibouti')
# Dominica - Roseau - insert into dev.raw_data.country_capital (country, capital) values ('Dominica', 'Roseau')
# Dominican Republic - Santo Domingo - insert into dev.raw_data.country_capital (country, capital) values ('Dominican Republic', 'Santo Domingo')
# East Timor (Timor-Leste) - Dili - insert into dev.raw_data.country_capital (country, capital) values ('East Timor (Timor-Leste)', 'Dili')
# Easter Island - Hanga Roa - insert into dev.raw_data.country_capital (country, capital) values ('Easter Island', 'Hanga Roa')
# Ecuador - Quito - insert into dev.raw_data.country_capital (country, capital) values ('Ecuador', 'Quito')
# Egypt - Cairo - insert into dev.raw_data.country_capital (country, capital) values ('Egypt', 'Cairo')
# El Salvador - San Salvador - insert into dev.raw_data.country_capital (country, capital) values ('El Salvador', 'San Salvador')
# Equatorial Guinea - Malabo - insert into dev.raw_data.country_capital (country, capital) values ('Equatorial Guinea', 'Malabo')
# Eritrea - Asmara - insert into dev.raw_data.country_capital (country, capital) values ('Eritrea', 'Asmara')
# Estonia - Tallinn - insert into dev.raw_data.country_capital (country, capital) values ('Estonia', 'Tallinn')
# Ethiopia - Addis Ababa - insert into dev.raw_data.country_capital (country, capital) values ('Ethiopia', 'Addis Ababa')
# Falkland Islands - Stanley - insert into dev.raw_data.country_capital (country, capital) values ('Falkland Islands', 'Stanley')
# Faroe Islands - Tââ¥rshavn - insert into dev.raw_data.country_capital (country, capital) values ('Faroe Islands', 'Tââ¥rshavn')
# Federated States of Micronesia - Palikir - insert into dev.raw_data.country_capital (country, capital) values ('Federated States of Micronesia', 'Palikir')
# Fiji - Suva - insert into dev.raw_data.country_capital (country, capital) values ('Fiji', 'Suva')
# Finland - Helsinki - insert into dev.raw_data.country_capital (country, capital) values ('Finland', 'Helsinki')
# France - Paris - insert into dev.raw_data.country_capital (country, capital) values ('France', 'Paris')
# French Guiana - Cayenne - insert into dev.raw_data.country_capital (country, capital) values ('French Guiana', 'Cayenne')
# French Polynesia - Papeete - insert into dev.raw_data.country_capital (country, capital) values ('French Polynesia', 'Papeete')
# Gabon - Libreville - insert into dev.raw_data.country_capital (country, capital) values ('Gabon', 'Libreville')
# Gambia - Banjul - insert into dev.raw_data.country_capital (country, capital) values ('Gambia', 'Banjul')
# Georgia - Tbilisi - insert into dev.raw_data.country_capital (country, capital) values ('Georgia', 'Tbilisi')
# Germany - Berlin - insert into dev.raw_data.country_capital (country, capital) values ('Germany', 'Berlin')
# Ghana - Accra - insert into dev.raw_data.country_capital (country, capital) values ('Ghana', 'Accra')
# Gibraltar - Gibraltar - insert into dev.raw_data.country_capital (country, capital) values ('Gibraltar', 'Gibraltar')
# Greece - Athens - insert into dev.raw_data.country_capital (country, capital) values ('Greece', 'Athens')
# Greenland - Nuuk - insert into dev.raw_data.country_capital (country, capital) values ('Greenland', 'Nuuk')
# Grenada - St. George''s - insert into dev.raw_data.country_capital (country, capital) values ('Grenada', 'St. George''s')
# Guam - Hagââ¢tâÂ±a - insert into dev.raw_data.country_capital (country, capital) values ('Guam', 'Hagââ¢tâÂ±a')
# Guatemala - Guatemala City - insert into dev.raw_data.country_capital (country, capital) values ('Guatemala', 'Guatemala City')
# Guernsey - St. Peter Port - insert into dev.raw_data.country_capital (country, capital) values ('Guernsey', 'St. Peter Port')
# Guinea - Conakry - insert into dev.raw_data.country_capital (country, capital) values ('Guinea', 'Conakry')
# Guinea-Bissau - Bissau - insert into dev.raw_data.country_capital (country, capital) values ('Guinea-Bissau', 'Bissau')
# Guyana - Georgetown - insert into dev.raw_data.country_capital (country, capital) values ('Guyana', 'Georgetown')
# Haiti - Port-au-Prince - insert into dev.raw_data.country_capital (country, capital) values ('Haiti', 'Port-au-Prince')
# Honduras - Tegucigalpa - insert into dev.raw_data.country_capital (country, capital) values ('Honduras', 'Tegucigalpa')
# Hungary - Budapest - insert into dev.raw_data.country_capital (country, capital) values ('Hungary', 'Budapest')
# Iceland - Reykjavââ k - insert into dev.raw_data.country_capital (country, capital) values ('Iceland', 'Reykjavââ k')
# India - New Delhi - insert into dev.raw_data.country_capital (country, capital) values ('India', 'New Delhi')
# Indonesia - Jakarta - insert into dev.raw_data.country_capital (country, capital) values ('Indonesia', 'Jakarta')
# Iran - Tehran - insert into dev.raw_data.country_capital (country, capital) values ('Iran', 'Tehran')
# Iraq - Baghdad - insert into dev.raw_data.country_capital (country, capital) values ('Iraq', 'Baghdad')
# Ireland - Dublin - insert into dev.raw_data.country_capital (country, capital) values ('Ireland', 'Dublin')
# Isle of Man - Douglas - insert into dev.raw_data.country_capital (country, capital) values ('Isle of Man', 'Douglas')
# Israel - Jerusalem - insert into dev.raw_data.country_capital (country, capital) values ('Israel', 'Jerusalem')
# Italy - Rome - insert into dev.raw_data.country_capital (country, capital) values ('Italy', 'Rome')
# Jamaica - Kingston - insert into dev.raw_data.country_capital (country, capital) values ('Jamaica', 'Kingston')
# Japan - Tokyo - insert into dev.raw_data.country_capital (country, capital) values ('Japan', 'Tokyo')
# Jersey - St. Helier - insert into dev.raw_data.country_capital (country, capital) values ('Jersey', 'St. Helier')
# Jordan - Amman - insert into dev.raw_data.country_capital (country, capital) values ('Jordan', 'Amman')
# Kazakhstan - Astana - insert into dev.raw_data.country_capital (country, capital) values ('Kazakhstan', 'Astana')
# Kenya - Nairobi - insert into dev.raw_data.country_capital (country, capital) values ('Kenya', 'Nairobi')
# Kiribati - Tarawa - insert into dev.raw_data.country_capital (country, capital) values ('Kiribati', 'Tarawa')
# Kosovo - Pristina - insert into dev.raw_data.country_capital (country, capital) values ('Kosovo', 'Pristina')
# Kuwait - Kuwait City - insert into dev.raw_data.country_capital (country, capital) values ('Kuwait', 'Kuwait City')
# Kyrgyzstan - Bishkek - insert into dev.raw_data.country_capital (country, capital) values ('Kyrgyzstan', 'Bishkek')
# Laos - Vientiane - insert into dev.raw_data.country_capital (country, capital) values ('Laos', 'Vientiane')
# Latvia - Riga - insert into dev.raw_data.country_capital (country, capital) values ('Latvia', 'Riga')
# Lebanon - Beirut - insert into dev.raw_data.country_capital (country, capital) values ('Lebanon', 'Beirut')
# Lesotho - Maseru - insert into dev.raw_data.country_capital (country, capital) values ('Lesotho', 'Maseru')
# Liberia - Monrovia - insert into dev.raw_data.country_capital (country, capital) values ('Liberia', 'Monrovia')
# Libya - Tripoli - insert into dev.raw_data.country_capital (country, capital) values ('Libya', 'Tripoli')
# Liechtenstein - Vaduz - insert into dev.raw_data.country_capital (country, capital) values ('Liechtenstein', 'Vaduz')
# Lithuania - Vilnius - insert into dev.raw_data.country_capital (country, capital) values ('Lithuania', 'Vilnius')
# Luxembourg - Luxembourg - insert into dev.raw_data.country_capital (country, capital) values ('Luxembourg', 'Luxembourg')
# Macedonia - Skopje - insert into dev.raw_data.country_capital (country, capital) values ('Macedonia', 'Skopje')
# Madagascar - Antananarivo - insert into dev.raw_data.country_capital (country, capital) values ('Madagascar', 'Antananarivo')
# Malawi - Lilongwe - insert into dev.raw_data.country_capital (country, capital) values ('Malawi', 'Lilongwe')
# Malaysia - Kuala Lumpur - insert into dev.raw_data.country_capital (country, capital) values ('Malaysia', 'Kuala Lumpur')
# Maldives - MalâÂ© - insert into dev.raw_data.country_capital (country, capital) values ('Maldives', 'MalâÂ©')
# Mali - Bamako - insert into dev.raw_data.country_capital (country, capital) values ('Mali', 'Bamako')
# Malta - Valletta - insert into dev.raw_data.country_capital (country, capital) values ('Malta', 'Valletta')
# Marshall Islands - Majuro - insert into dev.raw_data.country_capital (country, capital) values ('Marshall Islands', 'Majuro')
# Mauritania - Nouakchott - insert into dev.raw_data.country_capital (country, capital) values ('Mauritania', 'Nouakchott')
# Mauritius - Port Louis - insert into dev.raw_data.country_capital (country, capital) values ('Mauritius', 'Port Louis')
# Mexico - Mexico City - insert into dev.raw_data.country_capital (country, capital) values ('Mexico', 'Mexico City')
# Moldova - Chisinau - insert into dev.raw_data.country_capital (country, capital) values ('Moldova', 'Chisinau')
# Monaco - Monaco - insert into dev.raw_data.country_capital (country, capital) values ('Monaco', 'Monaco')
# Mongolia - Ulaanbaatar - insert into dev.raw_data.country_capital (country, capital) values ('Mongolia', 'Ulaanbaatar')
# Montenegro - Podgorica - insert into dev.raw_data.country_capital (country, capital) values ('Montenegro', 'Podgorica')
# Montserrat - Plymouth - insert into dev.raw_data.country_capital (country, capital) values ('Montserrat', 'Plymouth')
# Morocco - Rabat - insert into dev.raw_data.country_capital (country, capital) values ('Morocco', 'Rabat')
# Mozambique - Maputo - insert into dev.raw_data.country_capital (country, capital) values ('Mozambique', 'Maputo')
# Myanmar - Naypyidaw - insert into dev.raw_data.country_capital (country, capital) values ('Myanmar', 'Naypyidaw')
# Nagorno-Karabakh Republic - Stepanakert - insert into dev.raw_data.country_capital (country, capital) values ('Nagorno-Karabakh Republic', 'Stepanakert')
# Namibia - Windhoek - insert into dev.raw_data.country_capital (country, capital) values ('Namibia', 'Windhoek')
# Nauru - Yaren - insert into dev.raw_data.country_capital (country, capital) values ('Nauru', 'Yaren')
# Nepal - Kathmandu - insert into dev.raw_data.country_capital (country, capital) values ('Nepal', 'Kathmandu')
# Netherlands - Amsterdam - insert into dev.raw_data.country_capital (country, capital) values ('Netherlands', 'Amsterdam')
# New Caledonia - NoumâÂ©a - insert into dev.raw_data.country_capital (country, capital) values ('New Caledonia', 'NoumâÂ©a')
# New Zealand - Wellington - insert into dev.raw_data.country_capital (country, capital) values ('New Zealand', 'Wellington')
# Nicaragua - Managua - insert into dev.raw_data.country_capital (country, capital) values ('Nicaragua', 'Managua')
# Niger - Niamey - insert into dev.raw_data.country_capital (country, capital) values ('Niger', 'Niamey')
# Nigeria - Abuja - insert into dev.raw_data.country_capital (country, capital) values ('Nigeria', 'Abuja')
# Niue - Alofi - insert into dev.raw_data.country_capital (country, capital) values ('Niue', 'Alofi')
# Norfolk Island - Kingston - insert into dev.raw_data.country_capital (country, capital) values ('Norfolk Island', 'Kingston')
# North Korea - Pyongyang - insert into dev.raw_data.country_capital (country, capital) values ('North Korea', 'Pyongyang')
# Northern Cyprus - Nicosia - insert into dev.raw_data.country_capital (country, capital) values ('Northern Cyprus', 'Nicosia')
# United Kingdom Northern Ireland - Belfast - insert into dev.raw_data.country_capital (country, capital) values ('United Kingdom Northern Ireland', 'Belfast')
# Northern Mariana Islands - Saipan - insert into dev.raw_data.country_capital (country, capital) values ('Northern Mariana Islands', 'Saipan')
# Norway - Oslo - insert into dev.raw_data.country_capital (country, capital) values ('Norway', 'Oslo')
# Oman - Muscat - insert into dev.raw_data.country_capital (country, capital) values ('Oman', 'Muscat')
# Pakistan - Islamabad - insert into dev.raw_data.country_capital (country, capital) values ('Pakistan', 'Islamabad')
# Palau - Ngerulmud - insert into dev.raw_data.country_capital (country, capital) values ('Palau', 'Ngerulmud')
# Palestine - Jerusalem - insert into dev.raw_data.country_capital (country, capital) values ('Palestine', 'Jerusalem')
# Panama - Panama City - insert into dev.raw_data.country_capital (country, capital) values ('Panama', 'Panama City')
# Papua New Guinea - Port Moresby - insert into dev.raw_data.country_capital (country, capital) values ('Papua New Guinea', 'Port Moresby')
# Paraguay - Asunciââ¥n - insert into dev.raw_data.country_capital (country, capital) values ('Paraguay', 'Asunciââ¥n')
# Peru - Lima - insert into dev.raw_data.country_capital (country, capital) values ('Peru', 'Lima')
# Philippines - Manila - insert into dev.raw_data.country_capital (country, capital) values ('Philippines', 'Manila')
# Pitcairn Islands - Adamstown - insert into dev.raw_data.country_capital (country, capital) values ('Pitcairn Islands', 'Adamstown')
# Poland - Warsaw - insert into dev.raw_data.country_capital (country, capital) values ('Poland', 'Warsaw')
# Portugal - Lisbon - insert into dev.raw_data.country_capital (country, capital) values ('Portugal', 'Lisbon')
# Puerto Rico - San Juan - insert into dev.raw_data.country_capital (country, capital) values ('Puerto Rico', 'San Juan')
# Qatar - Doha - insert into dev.raw_data.country_capital (country, capital) values ('Qatar', 'Doha')
# Republic of China (Taiwan) - Taipei - insert into dev.raw_data.country_capital (country, capital) values ('Republic of China (Taiwan)', 'Taipei')
# Republic of the Congo - Brazzaville - insert into dev.raw_data.country_capital (country, capital) values ('Republic of the Congo', 'Brazzaville')
# Romania - Bucharest - insert into dev.raw_data.country_capital (country, capital) values ('Romania', 'Bucharest')
# Russia - Moscow - insert into dev.raw_data.country_capital (country, capital) values ('Russia', 'Moscow')
# Rwanda - Kigali - insert into dev.raw_data.country_capital (country, capital) values ('Rwanda', 'Kigali')
# Saint BarthâÂ©lemy - Gustavia - insert into dev.raw_data.country_capital (country, capital) values ('Saint BarthâÂ©lemy', 'Gustavia')
# Saint Helena - Jamestown - insert into dev.raw_data.country_capital (country, capital) values ('Saint Helena', 'Jamestown')
# Saint Kitts and Nevis - Basseterre - insert into dev.raw_data.country_capital (country, capital) values ('Saint Kitts and Nevis', 'Basseterre')
# Saint Lucia - Castries - insert into dev.raw_data.country_capital (country, capital) values ('Saint Lucia', 'Castries')
# Saint Martin - Marigot - insert into dev.raw_data.country_capital (country, capital) values ('Saint Martin', 'Marigot')
# Saint Pierre and Miquelon - St. Pierre - insert into dev.raw_data.country_capital (country, capital) values ('Saint Pierre and Miquelon', 'St. Pierre')
# Saint Vincent and the Grenadines - Kingstown - insert into dev.raw_data.country_capital (country, capital) values ('Saint Vincent and the Grenadines', 'Kingstown')
# Samoa - Apia - insert into dev.raw_data.country_capital (country, capital) values ('Samoa', 'Apia')
# San Marino - San Marino - insert into dev.raw_data.country_capital (country, capital) values ('San Marino', 'San Marino')
# Saudi Arabia - Riyadh - insert into dev.raw_data.country_capital (country, capital) values ('Saudi Arabia', 'Riyadh')
# Scotland - Edinburgh - insert into dev.raw_data.country_capital (country, capital) values ('Scotland', 'Edinburgh')
# Senegal - Dakar - insert into dev.raw_data.country_capital (country, capital) values ('Senegal', 'Dakar')
# Serbia - Belgrade - insert into dev.raw_data.country_capital (country, capital) values ('Serbia', 'Belgrade')
# Seychelles - Victoria - insert into dev.raw_data.country_capital (country, capital) values ('Seychelles', 'Victoria')
# Sierra Leone - Freetown - insert into dev.raw_data.country_capital (country, capital) values ('Sierra Leone', 'Freetown')
# Singapore - Singapore - insert into dev.raw_data.country_capital (country, capital) values ('Singapore', 'Singapore')
# Sint Maarten - Philipsburg - insert into dev.raw_data.country_capital (country, capital) values ('Sint Maarten', 'Philipsburg')
# Slovakia - Bratislava - insert into dev.raw_data.country_capital (country, capital) values ('Slovakia', 'Bratislava')
# Slovenia - Ljubljana - insert into dev.raw_data.country_capital (country, capital) values ('Slovenia', 'Ljubljana')
# Solomon Islands - Honiara - insert into dev.raw_data.country_capital (country, capital) values ('Solomon Islands', 'Honiara')
# Somalia - Mogadishu - insert into dev.raw_data.country_capital (country, capital) values ('Somalia', 'Mogadishu')
# Somaliland - Hargeisa - insert into dev.raw_data.country_capital (country, capital) values ('Somaliland', 'Hargeisa')
# South Africa - Pretoria - insert into dev.raw_data.country_capital (country, capital) values ('South Africa', 'Pretoria')
# South Georgia and the South Sandwich Islands - Grytviken - insert into dev.raw_data.country_capital (country, capital) values ('South Georgia and the South Sandwich Islands', 'Grytviken')
# South Korea - Seoul - insert into dev.raw_data.country_capital (country, capital) values ('South Korea', 'Seoul')
# South Ossetia - Tskhinvali - insert into dev.raw_data.country_capital (country, capital) values ('South Ossetia', 'Tskhinvali')
# South Sudan - Juba - insert into dev.raw_data.country_capital (country, capital) values ('South Sudan', 'Juba')
# Spain - Madrid - insert into dev.raw_data.country_capital (country, capital) values ('Spain', 'Madrid')
# Sri Lanka - Sri Jayawardenapura Kotte - insert into dev.raw_data.country_capital (country, capital) values ('Sri Lanka', 'Sri Jayawardenapura Kotte')
# Sudan - Khartoum - insert into dev.raw_data.country_capital (country, capital) values ('Sudan', 'Khartoum')
# Suriname - Paramaribo - insert into dev.raw_data.country_capital (country, capital) values ('Suriname', 'Paramaribo')
# Swaziland - Mbabane - insert into dev.raw_data.country_capital (country, capital) values ('Swaziland', 'Mbabane')
# Sweden - Stockholm - insert into dev.raw_data.country_capital (country, capital) values ('Sweden', 'Stockholm')
# Switzerland - Bern - insert into dev.raw_data.country_capital (country, capital) values ('Switzerland', 'Bern')
# Syria - Damascus - insert into dev.raw_data.country_capital (country, capital) values ('Syria', 'Damascus')
# SâÂ£o TomâÂ© and Prââ ncipe - SâÂ£o TomâÂ© - insert into dev.raw_data.country_capital (country, capital) values ('SâÂ£o TomâÂ© and Prââ ncipe', 'SâÂ£o TomâÂ©')
# Tajikistan - Dushanbe - insert into dev.raw_data.country_capital (country, capital) values ('Tajikistan', 'Dushanbe')
# Tanzania - Dodoma - insert into dev.raw_data.country_capital (country, capital) values ('Tanzania', 'Dodoma')
# Thailand - Bangkok - insert into dev.raw_data.country_capital (country, capital) values ('Thailand', 'Bangkok')
# Togo - LomâÂ© - insert into dev.raw_data.country_capital (country, capital) values ('Togo', 'LomâÂ©')
# Tonga - NukuÂ Âªalofa - insert into dev.raw_data.country_capital (country, capital) values ('Tonga', 'NukuÂ Âªalofa')
# Transnistria - Tiraspol - insert into dev.raw_data.country_capital (country, capital) values ('Transnistria', 'Tiraspol')
# Trinidad and Tobago - Port of Spain - insert into dev.raw_data.country_capital (country, capital) values ('Trinidad and Tobago', 'Port of Spain')
# Tristan da Cunha - Edinburgh of the Seven Seas - insert into dev.raw_data.country_capital (country, capital) values ('Tristan da Cunha', 'Edinburgh of the Seven Seas')
# Tunisia - Tunis - insert into dev.raw_data.country_capital (country, capital) values ('Tunisia', 'Tunis')
# Turkey - Ankara - insert into dev.raw_data.country_capital (country, capital) values ('Turkey', 'Ankara')
# Turkmenistan - Ashgabat - insert into dev.raw_data.country_capital (country, capital) values ('Turkmenistan', 'Ashgabat')
# Turks and Caicos Islands - Cockburn Town - insert into dev.raw_data.country_capital (country, capital) values ('Turks and Caicos Islands', 'Cockburn Town')
# Tuvalu - Funafuti - insert into dev.raw_data.country_capital (country, capital) values ('Tuvalu', 'Funafuti')
# Uganda - Kampala - insert into dev.raw_data.country_capital (country, capital) values ('Uganda', 'Kampala')
# Ukraine - Kyiv - insert into dev.raw_data.country_capital (country, capital) values ('Ukraine', 'Kyiv')
# United Arab Emirates - Abu Dhabi - insert into dev.raw_data.country_capital (country, capital) values ('United Arab Emirates', 'Abu Dhabi')
# United Kingdom; England - London - insert into dev.raw_data.country_capital (country, capital) values ('United Kingdom; England', 'London')
# United States - Washington D.C. - insert into dev.raw_data.country_capital (country, capital) values ('United States', 'Washington D.C.')
# United States Virgin Islands - Charlotte Amalie - insert into dev.raw_data.country_capital (country, capital) values ('United States Virgin Islands', 'Charlotte Amalie')
# Uruguay - Montevideo - insert into dev.raw_data.country_capital (country, capital) values ('Uruguay', 'Montevideo')
# Uzbekistan - Tashkent - insert into dev.raw_data.country_capital (country, capital) values ('Uzbekistan', 'Tashkent')
# Vanuatu - Port Vila - insert into dev.raw_data.country_capital (country, capital) values ('Vanuatu', 'Port Vila')
# Vatican City - Vatican City - insert into dev.raw_data.country_capital (country, capital) values ('Vatican City', 'Vatican City')
# Venezuela - Caracas - insert into dev.raw_data.country_capital (country, capital) values ('Venezuela', 'Caracas')
# Vietnam - Hanoi - insert into dev.raw_data.country_capital (country, capital) values ('Vietnam', 'Hanoi')
# Wales - Cardiff - insert into dev.raw_data.country_capital (country, capital) values ('Wales', 'Cardiff')
# Wallis and Futuna - Mata-Utu - insert into dev.raw_data.country_capital (country, capital) values ('Wallis and Futuna', 'Mata-Utu')
# Western Sahara - El Aaiââ«n - insert into dev.raw_data.country_capital (country, capital) values ('Western Sahara', 'El Aaiââ«n')
# Yemen - SanaâÂ° - insert into dev.raw_data.country_capital (country, capital) values ('Yemen', 'SanaâÂ°')
# Zambia - Lusaka - insert into dev.raw_data.country_capital (country, capital) values ('Zambia', 'Lusaka')
# Zimbabwe - Harare - insert into dev.raw_data.country_capital (country, capital) values ('Zimbabwe', 'Harare')

# %%
# table를 읽어서 판다스 데이터프레임으로 변환하고 처음 5개의 레코드와 레코드 수를 표시
def check_table_stats(cur, table, key):
    result = cur.execute(f"SELECT * FROM {table} ORDER BY {key}")
    df = cur.fetch_pandas_all()
    print(len(df))
    print(df.head())
    return df

# %%
check_table_stats(cur, "dev.raw_data.country_capital", "country")
# Out:
# 495
#                  COUNTRY              CAPITAL
# 0               Abkhazia              Sukhumi
# 1               Abkhazia              Sukhumi
# 2            Afghanistan                Kabul
# 3            Afghanistan                Kabul
# 4  Akrotiri and Dhekelia  Episkopi Cantonment
#                    COUNTRY              CAPITAL
# 0                 Abkhazia              Sukhumi
# 1                 Abkhazia              Sukhumi
# 2              Afghanistan                Kabul
# 3              Afghanistan                Kabul
# 4    Akrotiri and Dhekelia  Episkopi Cantonment
# ..                     ...                  ...
# 490                 Zambia               Lusaka
# 491                 Zambia               Lusaka
# 492               Zimbabwe               Harare
# 493               Zimbabwe               Harare
# 494                country              capital
#
# [495 rows x 2 columns]

# %%
data = extract(link)
lines = transform(data)
cur = return_snowflake_conn()
load(cur, lines)
# Out:
# country - capital - insert into dev.raw_data.country_capital (country, capital) values ('country', 'capital')
# Abkhazia - Sukhumi - insert into dev.raw_data.country_capital (country, capital) values ('Abkhazia', 'Sukhumi')
# Afghanistan - Kabul - insert into dev.raw_data.country_capital (country, capital) values ('Afghanistan', 'Kabul')
# Akrotiri and Dhekelia - Episkopi Cantonment - insert into dev.raw_data.country_capital (country, capital) values ('Akrotiri and Dhekelia', 'Episkopi Cantonment')
# Albania - Tirana - insert into dev.raw_data.country_capital (country, capital) values ('Albania', 'Tirana')
# Algeria - Algiers - insert into dev.raw_data.country_capital (country, capital) values ('Algeria', 'Algiers')
# American Samoa - Pago Pago - insert into dev.raw_data.country_capital (country, capital) values ('American Samoa', 'Pago Pago')
# Andorra - Andorra la Vella - insert into dev.raw_data.country_capital (country, capital) values ('Andorra', 'Andorra la Vella')
# Angola - Luanda - insert into dev.raw_data.country_capital (country, capital) values ('Angola', 'Luanda')
# Anguilla - The Valley - insert into dev.raw_data.country_capital (country, capital) values ('Anguilla', 'The Valley')
# Antigua and Barbuda - St. John''s - insert into dev.raw_data.country_capital (country, capital) values ('Antigua and Barbuda', 'St. John''s')
# Argentina - Buenos Aires - insert into dev.raw_data.country_capital (country, capital) values ('Argentina', 'Buenos Aires')
# Armenia - Yerevan - insert into dev.raw_data.country_capital (country, capital) values ('Armenia', 'Yerevan')
# Aruba - Oranjestad - insert into dev.raw_data.country_capital (country, capital) values ('Aruba', 'Oranjestad')
# Ascension Island - Georgetown - insert into dev.raw_data.country_capital (country, capital) values ('Ascension Island', 'Georgetown')
# Australia - Canberra - insert into dev.raw_data.country_capital (country, capital) values ('Australia', 'Canberra')
# Austria - Vienna - insert into dev.raw_data.country_capital (country, capital) values ('Austria', 'Vienna')
# Azerbaijan - Baku - insert into dev.raw_data.country_capital (country, capital) values ('Azerbaijan', 'Baku')
# Bahamas - Nassau - insert into dev.raw_data.country_capital (country, capital) values ('Bahamas', 'Nassau')
# Bahrain - Manama - insert into dev.raw_data.country_capital (country, capital) values ('Bahrain', 'Manama')
# Bangladesh - Dhaka - insert into dev.raw_data.country_capital (country, capital) values ('Bangladesh', 'Dhaka')
# Barbados - Bridgetown - insert into dev.raw_data.country_capital (country, capital) values ('Barbados', 'Bridgetown')
# Belarus - Minsk - insert into dev.raw_data.country_capital (country, capital) values ('Belarus', 'Minsk')
# Belgium - Brussels - insert into dev.raw_data.country_capital (country, capital) values ('Belgium', 'Brussels')
# Belize - Belmopan - insert into dev.raw_data.country_capital (country, capital) values ('Belize', 'Belmopan')
# Benin - Porto-Novo - insert into dev.raw_data.country_capital (country, capital) values ('Benin', 'Porto-Novo')
# Bermuda - Hamilton - insert into dev.raw_data.country_capital (country, capital) values ('Bermuda', 'Hamilton')
# Bhutan - Thimphu - insert into dev.raw_data.country_capital (country, capital) values ('Bhutan', 'Thimphu')
# Bolivia - La Paz - insert into dev.raw_data.country_capital (country, capital) values ('Bolivia', 'La Paz')
# Bosnia and Herzegovina - Sarajevo - insert into dev.raw_data.country_capital (country, capital) values ('Bosnia and Herzegovina', 'Sarajevo')
# Botswana - Gaborone - insert into dev.raw_data.country_capital (country, capital) values ('Botswana', 'Gaborone')
# Brazil - Brasââ lia - insert into dev.raw_data.country_capital (country, capital) values ('Brazil', 'Brasââ lia')
# British Virgin Islands - Road Town - insert into dev.raw_data.country_capital (country, capital) values ('British Virgin Islands', 'Road Town')
# Brunei - Bandar Seri Begawan - insert into dev.raw_data.country_capital (country, capital) values ('Brunei', 'Bandar Seri Begawan')
# Bulgaria - Sofia - insert into dev.raw_data.country_capital (country, capital) values ('Bulgaria', 'Sofia')
# Burkina Faso - Ouagadougou - insert into dev.raw_data.country_capital (country, capital) values ('Burkina Faso', 'Ouagadougou')
# Burundi - Bujumbura - insert into dev.raw_data.country_capital (country, capital) values ('Burundi', 'Bujumbura')
# Cambodia - Phnom Penh - insert into dev.raw_data.country_capital (country, capital) values ('Cambodia', 'Phnom Penh')
# Cameroon - YaoundâÂ© - insert into dev.raw_data.country_capital (country, capital) values ('Cameroon', 'YaoundâÂ©')
# Canada - Ottawa - insert into dev.raw_data.country_capital (country, capital) values ('Canada', 'Ottawa')
# Cape Verde - Praia - insert into dev.raw_data.country_capital (country, capital) values ('Cape Verde', 'Praia')
# Cayman Islands - George Town - insert into dev.raw_data.country_capital (country, capital) values ('Cayman Islands', 'George Town')
# Central African Republic - Bangui - insert into dev.raw_data.country_capital (country, capital) values ('Central African Republic', 'Bangui')
# Chad - N''Djamena - insert into dev.raw_data.country_capital (country, capital) values ('Chad', 'N''Djamena')
# Chile - Santiago - insert into dev.raw_data.country_capital (country, capital) values ('Chile', 'Santiago')
# China - Beijing - insert into dev.raw_data.country_capital (country, capital) values ('China', 'Beijing')
# Christmas Island - Flying Fish Cove - insert into dev.raw_data.country_capital (country, capital) values ('Christmas Island', 'Flying Fish Cove')
# Cocos (Keeling) Islands - West Island - insert into dev.raw_data.country_capital (country, capital) values ('Cocos (Keeling) Islands', 'West Island')
# Colombia - BogotâÂ° - insert into dev.raw_data.country_capital (country, capital) values ('Colombia', 'BogotâÂ°')
# Comoros - Moroni - insert into dev.raw_data.country_capital (country, capital) values ('Comoros', 'Moroni')
# Cook Islands - Avarua - insert into dev.raw_data.country_capital (country, capital) values ('Cook Islands', 'Avarua')
# Costa Rica - San JosâÂ© - insert into dev.raw_data.country_capital (country, capital) values ('Costa Rica', 'San JosâÂ©')
# Croatia - Zagreb - insert into dev.raw_data.country_capital (country, capital) values ('Croatia', 'Zagreb')
# Cuba - Havana - insert into dev.raw_data.country_capital (country, capital) values ('Cuba', 'Havana')
# CuraâÃao - Willemstad - insert into dev.raw_data.country_capital (country, capital) values ('CuraâÃao', 'Willemstad')
# Cyprus - Nicosia - insert into dev.raw_data.country_capital (country, capital) values ('Cyprus', 'Nicosia')
# Czech Republic - Prague - insert into dev.raw_data.country_capital (country, capital) values ('Czech Republic', 'Prague')
# CâÂ¥te d''Ivoire - Yamoussoukro - insert into dev.raw_data.country_capital (country, capital) values ('CâÂ¥te d''Ivoire', 'Yamoussoukro')
# Democratic Republic of the Congo - Kinshasa - insert into dev.raw_data.country_capital (country, capital) values ('Democratic Republic of the Congo', 'Kinshasa')
# Denmark - Copenhagen - insert into dev.raw_data.country_capital (country, capital) values ('Denmark', 'Copenhagen')
# Djibouti - Djibouti - insert into dev.raw_data.country_capital (country, capital) values ('Djibouti', 'Djibouti')
# Dominica - Roseau - insert into dev.raw_data.country_capital (country, capital) values ('Dominica', 'Roseau')
# Dominican Republic - Santo Domingo - insert into dev.raw_data.country_capital (country, capital) values ('Dominican Republic', 'Santo Domingo')
# East Timor (Timor-Leste) - Dili - insert into dev.raw_data.country_capital (country, capital) values ('East Timor (Timor-Leste)', 'Dili')
# Easter Island - Hanga Roa - insert into dev.raw_data.country_capital (country, capital) values ('Easter Island', 'Hanga Roa')
# Ecuador - Quito - insert into dev.raw_data.country_capital (country, capital) values ('Ecuador', 'Quito')
# Egypt - Cairo - insert into dev.raw_data.country_capital (country, capital) values ('Egypt', 'Cairo')
# El Salvador - San Salvador - insert into dev.raw_data.country_capital (country, capital) values ('El Salvador', 'San Salvador')
# Equatorial Guinea - Malabo - insert into dev.raw_data.country_capital (country, capital) values ('Equatorial Guinea', 'Malabo')
# Eritrea - Asmara - insert into dev.raw_data.country_capital (country, capital) values ('Eritrea', 'Asmara')
# Estonia - Tallinn - insert into dev.raw_data.country_capital (country, capital) values ('Estonia', 'Tallinn')
# Ethiopia - Addis Ababa - insert into dev.raw_data.country_capital (country, capital) values ('Ethiopia', 'Addis Ababa')
# Falkland Islands - Stanley - insert into dev.raw_data.country_capital (country, capital) values ('Falkland Islands', 'Stanley')
# Faroe Islands - Tââ¥rshavn - insert into dev.raw_data.country_capital (country, capital) values ('Faroe Islands', 'Tââ¥rshavn')
# Federated States of Micronesia - Palikir - insert into dev.raw_data.country_capital (country, capital) values ('Federated States of Micronesia', 'Palikir')
# Fiji - Suva - insert into dev.raw_data.country_capital (country, capital) values ('Fiji', 'Suva')
# Finland - Helsinki - insert into dev.raw_data.country_capital (country, capital) values ('Finland', 'Helsinki')
# France - Paris - insert into dev.raw_data.country_capital (country, capital) values ('France', 'Paris')
# French Guiana - Cayenne - insert into dev.raw_data.country_capital (country, capital) values ('French Guiana', 'Cayenne')
# French Polynesia - Papeete - insert into dev.raw_data.country_capital (country, capital) values ('French Polynesia', 'Papeete')
# Gabon - Libreville - insert into dev.raw_data.country_capital (country, capital) values ('Gabon', 'Libreville')
# Gambia - Banjul - insert into dev.raw_data.country_capital (country, capital) values ('Gambia', 'Banjul')
# Georgia - Tbilisi - insert into dev.raw_data.country_capital (country, capital) values ('Georgia', 'Tbilisi')
# Germany - Berlin - insert into dev.raw_data.country_capital (country, capital) values ('Germany', 'Berlin')
# Ghana - Accra - insert into dev.raw_data.country_capital (country, capital) values ('Ghana', 'Accra')
# Gibraltar - Gibraltar - insert into dev.raw_data.country_capital (country, capital) values ('Gibraltar', 'Gibraltar')
# Greece - Athens - insert into dev.raw_data.country_capital (country, capital) values ('Greece', 'Athens')
# Greenland - Nuuk - insert into dev.raw_data.country_capital (country, capital) values ('Greenland', 'Nuuk')
# Grenada - St. George''s - insert into dev.raw_data.country_capital (country, capital) values ('Grenada', 'St. George''s')
# Guam - Hagââ¢tâÂ±a - insert into dev.raw_data.country_capital (country, capital) values ('Guam', 'Hagââ¢tâÂ±a')
# Guatemala - Guatemala City - insert into dev.raw_data.country_capital (country, capital) values ('Guatemala', 'Guatemala City')
# Guernsey - St. Peter Port - insert into dev.raw_data.country_capital (country, capital) values ('Guernsey', 'St. Peter Port')
# Guinea - Conakry - insert into dev.raw_data.country_capital (country, capital) values ('Guinea', 'Conakry')
# Guinea-Bissau - Bissau - insert into dev.raw_data.country_capital (country, capital) values ('Guinea-Bissau', 'Bissau')
# Guyana - Georgetown - insert into dev.raw_data.country_capital (country, capital) values ('Guyana', 'Georgetown')
# Haiti - Port-au-Prince - insert into dev.raw_data.country_capital (country, capital) values ('Haiti', 'Port-au-Prince')
# Honduras - Tegucigalpa - insert into dev.raw_data.country_capital (country, capital) values ('Honduras', 'Tegucigalpa')
# Hungary - Budapest - insert into dev.raw_data.country_capital (country, capital) values ('Hungary', 'Budapest')
# Iceland - Reykjavââ k - insert into dev.raw_data.country_capital (country, capital) values ('Iceland', 'Reykjavââ k')
# India - New Delhi - insert into dev.raw_data.country_capital (country, capital) values ('India', 'New Delhi')
# Indonesia - Jakarta - insert into dev.raw_data.country_capital (country, capital) values ('Indonesia', 'Jakarta')
# Iran - Tehran - insert into dev.raw_data.country_capital (country, capital) values ('Iran', 'Tehran')
# Iraq - Baghdad - insert into dev.raw_data.country_capital (country, capital) values ('Iraq', 'Baghdad')
# Ireland - Dublin - insert into dev.raw_data.country_capital (country, capital) values ('Ireland', 'Dublin')
# Isle of Man - Douglas - insert into dev.raw_data.country_capital (country, capital) values ('Isle of Man', 'Douglas')
# Israel - Jerusalem - insert into dev.raw_data.country_capital (country, capital) values ('Israel', 'Jerusalem')
# Italy - Rome - insert into dev.raw_data.country_capital (country, capital) values ('Italy', 'Rome')
# Jamaica - Kingston - insert into dev.raw_data.country_capital (country, capital) values ('Jamaica', 'Kingston')
# Japan - Tokyo - insert into dev.raw_data.country_capital (country, capital) values ('Japan', 'Tokyo')
# Jersey - St. Helier - insert into dev.raw_data.country_capital (country, capital) values ('Jersey', 'St. Helier')
# Jordan - Amman - insert into dev.raw_data.country_capital (country, capital) values ('Jordan', 'Amman')
# Kazakhstan - Astana - insert into dev.raw_data.country_capital (country, capital) values ('Kazakhstan', 'Astana')
# Kenya - Nairobi - insert into dev.raw_data.country_capital (country, capital) values ('Kenya', 'Nairobi')
# Kiribati - Tarawa - insert into dev.raw_data.country_capital (country, capital) values ('Kiribati', 'Tarawa')
# Kosovo - Pristina - insert into dev.raw_data.country_capital (country, capital) values ('Kosovo', 'Pristina')
# Kuwait - Kuwait City - insert into dev.raw_data.country_capital (country, capital) values ('Kuwait', 'Kuwait City')
# Kyrgyzstan - Bishkek - insert into dev.raw_data.country_capital (country, capital) values ('Kyrgyzstan', 'Bishkek')
# Laos - Vientiane - insert into dev.raw_data.country_capital (country, capital) values ('Laos', 'Vientiane')
# Latvia - Riga - insert into dev.raw_data.country_capital (country, capital) values ('Latvia', 'Riga')
# Lebanon - Beirut - insert into dev.raw_data.country_capital (country, capital) values ('Lebanon', 'Beirut')
# Lesotho - Maseru - insert into dev.raw_data.country_capital (country, capital) values ('Lesotho', 'Maseru')
# Liberia - Monrovia - insert into dev.raw_data.country_capital (country, capital) values ('Liberia', 'Monrovia')
# Libya - Tripoli - insert into dev.raw_data.country_capital (country, capital) values ('Libya', 'Tripoli')
# Liechtenstein - Vaduz - insert into dev.raw_data.country_capital (country, capital) values ('Liechtenstein', 'Vaduz')
# Lithuania - Vilnius - insert into dev.raw_data.country_capital (country, capital) values ('Lithuania', 'Vilnius')
# Luxembourg - Luxembourg - insert into dev.raw_data.country_capital (country, capital) values ('Luxembourg', 'Luxembourg')
# Macedonia - Skopje - insert into dev.raw_data.country_capital (country, capital) values ('Macedonia', 'Skopje')
# Madagascar - Antananarivo - insert into dev.raw_data.country_capital (country, capital) values ('Madagascar', 'Antananarivo')
# Malawi - Lilongwe - insert into dev.raw_data.country_capital (country, capital) values ('Malawi', 'Lilongwe')
# Malaysia - Kuala Lumpur - insert into dev.raw_data.country_capital (country, capital) values ('Malaysia', 'Kuala Lumpur')
# Maldives - MalâÂ© - insert into dev.raw_data.country_capital (country, capital) values ('Maldives', 'MalâÂ©')
# Mali - Bamako - insert into dev.raw_data.country_capital (country, capital) values ('Mali', 'Bamako')
# Malta - Valletta - insert into dev.raw_data.country_capital (country, capital) values ('Malta', 'Valletta')
# Marshall Islands - Majuro - insert into dev.raw_data.country_capital (country, capital) values ('Marshall Islands', 'Majuro')
# Mauritania - Nouakchott - insert into dev.raw_data.country_capital (country, capital) values ('Mauritania', 'Nouakchott')
# Mauritius - Port Louis - insert into dev.raw_data.country_capital (country, capital) values ('Mauritius', 'Port Louis')
# Mexico - Mexico City - insert into dev.raw_data.country_capital (country, capital) values ('Mexico', 'Mexico City')
# Moldova - Chisinau - insert into dev.raw_data.country_capital (country, capital) values ('Moldova', 'Chisinau')
# Monaco - Monaco - insert into dev.raw_data.country_capital (country, capital) values ('Monaco', 'Monaco')
# Mongolia - Ulaanbaatar - insert into dev.raw_data.country_capital (country, capital) values ('Mongolia', 'Ulaanbaatar')
# Montenegro - Podgorica - insert into dev.raw_data.country_capital (country, capital) values ('Montenegro', 'Podgorica')
# Montserrat - Plymouth - insert into dev.raw_data.country_capital (country, capital) values ('Montserrat', 'Plymouth')
# Morocco - Rabat - insert into dev.raw_data.country_capital (country, capital) values ('Morocco', 'Rabat')
# Mozambique - Maputo - insert into dev.raw_data.country_capital (country, capital) values ('Mozambique', 'Maputo')
# Myanmar - Naypyidaw - insert into dev.raw_data.country_capital (country, capital) values ('Myanmar', 'Naypyidaw')
# Nagorno-Karabakh Republic - Stepanakert - insert into dev.raw_data.country_capital (country, capital) values ('Nagorno-Karabakh Republic', 'Stepanakert')
# Namibia - Windhoek - insert into dev.raw_data.country_capital (country, capital) values ('Namibia', 'Windhoek')
# Nauru - Yaren - insert into dev.raw_data.country_capital (country, capital) values ('Nauru', 'Yaren')
# Nepal - Kathmandu - insert into dev.raw_data.country_capital (country, capital) values ('Nepal', 'Kathmandu')
# Netherlands - Amsterdam - insert into dev.raw_data.country_capital (country, capital) values ('Netherlands', 'Amsterdam')
# New Caledonia - NoumâÂ©a - insert into dev.raw_data.country_capital (country, capital) values ('New Caledonia', 'NoumâÂ©a')
# New Zealand - Wellington - insert into dev.raw_data.country_capital (country, capital) values ('New Zealand', 'Wellington')
# Nicaragua - Managua - insert into dev.raw_data.country_capital (country, capital) values ('Nicaragua', 'Managua')
# Niger - Niamey - insert into dev.raw_data.country_capital (country, capital) values ('Niger', 'Niamey')
# Nigeria - Abuja - insert into dev.raw_data.country_capital (country, capital) values ('Nigeria', 'Abuja')
# Niue - Alofi - insert into dev.raw_data.country_capital (country, capital) values ('Niue', 'Alofi')
# Norfolk Island - Kingston - insert into dev.raw_data.country_capital (country, capital) values ('Norfolk Island', 'Kingston')
# North Korea - Pyongyang - insert into dev.raw_data.country_capital (country, capital) values ('North Korea', 'Pyongyang')
# Northern Cyprus - Nicosia - insert into dev.raw_data.country_capital (country, capital) values ('Northern Cyprus', 'Nicosia')
# United Kingdom Northern Ireland - Belfast - insert into dev.raw_data.country_capital (country, capital) values ('United Kingdom Northern Ireland', 'Belfast')
# Northern Mariana Islands - Saipan - insert into dev.raw_data.country_capital (country, capital) values ('Northern Mariana Islands', 'Saipan')
# Norway - Oslo - insert into dev.raw_data.country_capital (country, capital) values ('Norway', 'Oslo')
# Oman - Muscat - insert into dev.raw_data.country_capital (country, capital) values ('Oman', 'Muscat')
# Pakistan - Islamabad - insert into dev.raw_data.country_capital (country, capital) values ('Pakistan', 'Islamabad')
# Palau - Ngerulmud - insert into dev.raw_data.country_capital (country, capital) values ('Palau', 'Ngerulmud')
# Palestine - Jerusalem - insert into dev.raw_data.country_capital (country, capital) values ('Palestine', 'Jerusalem')
# Panama - Panama City - insert into dev.raw_data.country_capital (country, capital) values ('Panama', 'Panama City')
# Papua New Guinea - Port Moresby - insert into dev.raw_data.country_capital (country, capital) values ('Papua New Guinea', 'Port Moresby')
# Paraguay - Asunciââ¥n - insert into dev.raw_data.country_capital (country, capital) values ('Paraguay', 'Asunciââ¥n')
# Peru - Lima - insert into dev.raw_data.country_capital (country, capital) values ('Peru', 'Lima')
# Philippines - Manila - insert into dev.raw_data.country_capital (country, capital) values ('Philippines', 'Manila')
# Pitcairn Islands - Adamstown - insert into dev.raw_data.country_capital (country, capital) values ('Pitcairn Islands', 'Adamstown')
# Poland - Warsaw - insert into dev.raw_data.country_capital (country, capital) values ('Poland', 'Warsaw')
# Portugal - Lisbon - insert into dev.raw_data.country_capital (country, capital) values ('Portugal', 'Lisbon')
# Puerto Rico - San Juan - insert into dev.raw_data.country_capital (country, capital) values ('Puerto Rico', 'San Juan')
# Qatar - Doha - insert into dev.raw_data.country_capital (country, capital) values ('Qatar', 'Doha')
# Republic of China (Taiwan) - Taipei - insert into dev.raw_data.country_capital (country, capital) values ('Republic of China (Taiwan)', 'Taipei')
# Republic of the Congo - Brazzaville - insert into dev.raw_data.country_capital (country, capital) values ('Republic of the Congo', 'Brazzaville')
# Romania - Bucharest - insert into dev.raw_data.country_capital (country, capital) values ('Romania', 'Bucharest')
# Russia - Moscow - insert into dev.raw_data.country_capital (country, capital) values ('Russia', 'Moscow')
# Rwanda - Kigali - insert into dev.raw_data.country_capital (country, capital) values ('Rwanda', 'Kigali')
# Saint BarthâÂ©lemy - Gustavia - insert into dev.raw_data.country_capital (country, capital) values ('Saint BarthâÂ©lemy', 'Gustavia')
# Saint Helena - Jamestown - insert into dev.raw_data.country_capital (country, capital) values ('Saint Helena', 'Jamestown')
# Saint Kitts and Nevis - Basseterre - insert into dev.raw_data.country_capital (country, capital) values ('Saint Kitts and Nevis', 'Basseterre')
# Saint Lucia - Castries - insert into dev.raw_data.country_capital (country, capital) values ('Saint Lucia', 'Castries')
# Saint Martin - Marigot - insert into dev.raw_data.country_capital (country, capital) values ('Saint Martin', 'Marigot')
# Saint Pierre and Miquelon - St. Pierre - insert into dev.raw_data.country_capital (country, capital) values ('Saint Pierre and Miquelon', 'St. Pierre')
# Saint Vincent and the Grenadines - Kingstown - insert into dev.raw_data.country_capital (country, capital) values ('Saint Vincent and the Grenadines', 'Kingstown')
# Samoa - Apia - insert into dev.raw_data.country_capital (country, capital) values ('Samoa', 'Apia')
# San Marino - San Marino - insert into dev.raw_data.country_capital (country, capital) values ('San Marino', 'San Marino')
# Saudi Arabia - Riyadh - insert into dev.raw_data.country_capital (country, capital) values ('Saudi Arabia', 'Riyadh')
# Scotland - Edinburgh - insert into dev.raw_data.country_capital (country, capital) values ('Scotland', 'Edinburgh')
# Senegal - Dakar - insert into dev.raw_data.country_capital (country, capital) values ('Senegal', 'Dakar')
# Serbia - Belgrade - insert into dev.raw_data.country_capital (country, capital) values ('Serbia', 'Belgrade')
# Seychelles - Victoria - insert into dev.raw_data.country_capital (country, capital) values ('Seychelles', 'Victoria')
# Sierra Leone - Freetown - insert into dev.raw_data.country_capital (country, capital) values ('Sierra Leone', 'Freetown')
# Singapore - Singapore - insert into dev.raw_data.country_capital (country, capital) values ('Singapore', 'Singapore')
# Sint Maarten - Philipsburg - insert into dev.raw_data.country_capital (country, capital) values ('Sint Maarten', 'Philipsburg')
# Slovakia - Bratislava - insert into dev.raw_data.country_capital (country, capital) values ('Slovakia', 'Bratislava')
# Slovenia - Ljubljana - insert into dev.raw_data.country_capital (country, capital) values ('Slovenia', 'Ljubljana')
# Solomon Islands - Honiara - insert into dev.raw_data.country_capital (country, capital) values ('Solomon Islands', 'Honiara')
# Somalia - Mogadishu - insert into dev.raw_data.country_capital (country, capital) values ('Somalia', 'Mogadishu')
# Somaliland - Hargeisa - insert into dev.raw_data.country_capital (country, capital) values ('Somaliland', 'Hargeisa')
# South Africa - Pretoria - insert into dev.raw_data.country_capital (country, capital) values ('South Africa', 'Pretoria')
# South Georgia and the South Sandwich Islands - Grytviken - insert into dev.raw_data.country_capital (country, capital) values ('South Georgia and the South Sandwich Islands', 'Grytviken')
# South Korea - Seoul - insert into dev.raw_data.country_capital (country, capital) values ('South Korea', 'Seoul')
# South Ossetia - Tskhinvali - insert into dev.raw_data.country_capital (country, capital) values ('South Ossetia', 'Tskhinvali')
# South Sudan - Juba - insert into dev.raw_data.country_capital (country, capital) values ('South Sudan', 'Juba')
# Spain - Madrid - insert into dev.raw_data.country_capital (country, capital) values ('Spain', 'Madrid')
# Sri Lanka - Sri Jayawardenapura Kotte - insert into dev.raw_data.country_capital (country, capital) values ('Sri Lanka', 'Sri Jayawardenapura Kotte')
# Sudan - Khartoum - insert into dev.raw_data.country_capital (country, capital) values ('Sudan', 'Khartoum')
# Suriname - Paramaribo - insert into dev.raw_data.country_capital (country, capital) values ('Suriname', 'Paramaribo')
# Swaziland - Mbabane - insert into dev.raw_data.country_capital (country, capital) values ('Swaziland', 'Mbabane')
# Sweden - Stockholm - insert into dev.raw_data.country_capital (country, capital) values ('Sweden', 'Stockholm')
# Switzerland - Bern - insert into dev.raw_data.country_capital (country, capital) values ('Switzerland', 'Bern')
# Syria - Damascus - insert into dev.raw_data.country_capital (country, capital) values ('Syria', 'Damascus')
# SâÂ£o TomâÂ© and Prââ ncipe - SâÂ£o TomâÂ© - insert into dev.raw_data.country_capital (country, capital) values ('SâÂ£o TomâÂ© and Prââ ncipe', 'SâÂ£o TomâÂ©')
# Tajikistan - Dushanbe - insert into dev.raw_data.country_capital (country, capital) values ('Tajikistan', 'Dushanbe')
# Tanzania - Dodoma - insert into dev.raw_data.country_capital (country, capital) values ('Tanzania', 'Dodoma')
# Thailand - Bangkok - insert into dev.raw_data.country_capital (country, capital) values ('Thailand', 'Bangkok')
# Togo - LomâÂ© - insert into dev.raw_data.country_capital (country, capital) values ('Togo', 'LomâÂ©')
# Tonga - NukuÂ Âªalofa - insert into dev.raw_data.country_capital (country, capital) values ('Tonga', 'NukuÂ Âªalofa')
# Transnistria - Tiraspol - insert into dev.raw_data.country_capital (country, capital) values ('Transnistria', 'Tiraspol')
# Trinidad and Tobago - Port of Spain - insert into dev.raw_data.country_capital (country, capital) values ('Trinidad and Tobago', 'Port of Spain')
# Tristan da Cunha - Edinburgh of the Seven Seas - insert into dev.raw_data.country_capital (country, capital) values ('Tristan da Cunha', 'Edinburgh of the Seven Seas')
# Tunisia - Tunis - insert into dev.raw_data.country_capital (country, capital) values ('Tunisia', 'Tunis')
# Turkey - Ankara - insert into dev.raw_data.country_capital (country, capital) values ('Turkey', 'Ankara')
# Turkmenistan - Ashgabat - insert into dev.raw_data.country_capital (country, capital) values ('Turkmenistan', 'Ashgabat')
# Turks and Caicos Islands - Cockburn Town - insert into dev.raw_data.country_capital (country, capital) values ('Turks and Caicos Islands', 'Cockburn Town')
# Tuvalu - Funafuti - insert into dev.raw_data.country_capital (country, capital) values ('Tuvalu', 'Funafuti')
# Uganda - Kampala - insert into dev.raw_data.country_capital (country, capital) values ('Uganda', 'Kampala')
# Ukraine - Kyiv - insert into dev.raw_data.country_capital (country, capital) values ('Ukraine', 'Kyiv')
# United Arab Emirates - Abu Dhabi - insert into dev.raw_data.country_capital (country, capital) values ('United Arab Emirates', 'Abu Dhabi')
# United Kingdom; England - London - insert into dev.raw_data.country_capital (country, capital) values ('United Kingdom; England', 'London')
# United States - Washington D.C. - insert into dev.raw_data.country_capital (country, capital) values ('United States', 'Washington D.C.')
# United States Virgin Islands - Charlotte Amalie - insert into dev.raw_data.country_capital (country, capital) values ('United States Virgin Islands', 'Charlotte Amalie')
# Uruguay - Montevideo - insert into dev.raw_data.country_capital (country, capital) values ('Uruguay', 'Montevideo')
# Uzbekistan - Tashkent - insert into dev.raw_data.country_capital (country, capital) values ('Uzbekistan', 'Tashkent')
# Vanuatu - Port Vila - insert into dev.raw_data.country_capital (country, capital) values ('Vanuatu', 'Port Vila')
# Vatican City - Vatican City - insert into dev.raw_data.country_capital (country, capital) values ('Vatican City', 'Vatican City')
# Venezuela - Caracas - insert into dev.raw_data.country_capital (country, capital) values ('Venezuela', 'Caracas')
# Vietnam - Hanoi - insert into dev.raw_data.country_capital (country, capital) values ('Vietnam', 'Hanoi')
# Wales - Cardiff - insert into dev.raw_data.country_capital (country, capital) values ('Wales', 'Cardiff')
# Wallis and Futuna - Mata-Utu - insert into dev.raw_data.country_capital (country, capital) values ('Wallis and Futuna', 'Mata-Utu')
# Western Sahara - El Aaiââ«n - insert into dev.raw_data.country_capital (country, capital) values ('Western Sahara', 'El Aaiââ«n')
# Yemen - SanaâÂ° - insert into dev.raw_data.country_capital (country, capital) values ('Yemen', 'SanaâÂ°')
# Zambia - Lusaka - insert into dev.raw_data.country_capital (country, capital) values ('Zambia', 'Lusaka')
# Zimbabwe - Harare - insert into dev.raw_data.country_capital (country, capital) values ('Zimbabwe', 'Harare')

# %%
# 결과를 보면 Primary Key 유일성이 없음
# 데이터가 중복되어서 적재된 것으로 확인 
check_table_stats(cur, "dev.raw_data.country_capital", "country")
# Out:
# 743
#        COUNTRY  CAPITAL
# 0     Abkhazia  Sukhumi
# 1     Abkhazia  Sukhumi
# 2     Abkhazia  Sukhumi
# 3  Afghanistan    Kabul
# 4  Afghanistan    Kabul
#          COUNTRY  CAPITAL
# 0       Abkhazia  Sukhumi
# 1       Abkhazia  Sukhumi
# 2       Abkhazia  Sukhumi
# 3    Afghanistan    Kabul
# 4    Afghanistan    Kabul
# ..           ...      ...
# 738     Zimbabwe   Harare
# 739     Zimbabwe   Harare
# 740     Zimbabwe   Harare
# 741      country  capital
# 742      country  capital
#
# [743 rows x 2 columns]

# %% [markdown]
# ## 현재 문제점
# 1. 데이터 헤더도 같이 가져옴
# 2. 데이터가 중복되어 적재됨 -> 멱등성 위반
#  - 데이터를 삭제하고 전체 다시 적재 (전체 업데이트)
#  - 데이터를 날짜/시간 단위로 테이블을 업데이트 신규 혹은 변경 레코드만 복사 (증분업데이트)
#
# ## 해결
# 1. 값을 리턴할 때 1째줄 제외하고 가져오기
# 2. (데이터가 적을 때 쉽고 안전하게 바꿀 수 있는) 전체 업데이트 채택 그리고 트랜잭션 사용으로 (begin/commit/rollback) 멱등성 보장

# %%
# transform 함수를 개선해서 헤더를 빼고 리턴하게 만들자
def transform_v2(text):
    lines = text.strip().split("\n")
    records = []
    for l in lines:  # remove the first row
        (country, capital) = l.split(",")
        records.append([country, capital])
    return records[1:] # 여기서 첫번째 줄을 삭제 하고 리턴하도록 변경함

# %%
# load 함수를 개선해서 제대로 된 "Full refresh"를 구현하자
#  - 매번 테이블을 새로 만들고 레코드를 새로 적재하는 방식으로 구현
#  - SQL transaction을 사용하는 것이 일반적이지만 Snowflake은 SQL transaction을 지원하지
#    않기 때문에 다른 방식으로 구현
def load_v2(con, records):
    target_table = "dev.raw_data.country_capital"
    try:
        # 여기서 CREATE OR REPLACE TABLE이 사용되면 안됨. DDL이라 Snowflake에서는 transaction을 지키지 않기 때문
        con.execute(f"CREATE TABLE IF NOT EXISTS {target_table} (country varchar primary key, capital varchar);")
        con.execute("BEGIN;") # 작업의 한단위로 묶을거야. 하나라도 실패하면 전부 취소해 (begin / commit / rollback)
        con.execute(f"DELETE FROM {target_table};")
        for r in records:
            country = r[0].replace("'", "''")
            capital = r[1].replace("'", "''")
            print(country, "-", capital)

            sql = f"INSERT INTO {target_table} (country, capital) VALUES ('{country}', '{capital}')"
            con.execute(sql)
        con.execute("COMMIT;")
    except Exception as e:
        con.execute("ROLLBACK;")
        print(e)
        raise e

# %%
def country_capital_data_pipeline_v2(link):
    cur = return_snowflake_conn()# 커넥션을 얻어서 연결해줌
    data = extract(link) # 데이터 추출 
    lines = transform_v2(data) # 데이터 반환
    load_v2(cur, lines) # 데이터 적재 
    check_table_stats(cur, "dev.raw_data.country_capital", "country")
    cur.close()

# %%
link = "https://s3-geospatial.s3.us-west-2.amazonaws.com/country_capital.csv"
country_capital_data_pipeline_v2(link)
# Out:
# Abkhazia - Sukhumi
# Afghanistan - Kabul
# Akrotiri and Dhekelia - Episkopi Cantonment
# Albania - Tirana
# Algeria - Algiers
# American Samoa - Pago Pago
# Andorra - Andorra la Vella
# Angola - Luanda
# Anguilla - The Valley
# Antigua and Barbuda - St. John''s
# Argentina - Buenos Aires
# Armenia - Yerevan
# Aruba - Oranjestad
# Ascension Island - Georgetown
# Australia - Canberra
# Austria - Vienna
# Azerbaijan - Baku
# Bahamas - Nassau
# Bahrain - Manama
# Bangladesh - Dhaka
# Barbados - Bridgetown
# Belarus - Minsk
# Belgium - Brussels
# Belize - Belmopan
# Benin - Porto-Novo
# Bermuda - Hamilton
# Bhutan - Thimphu
# Bolivia - La Paz
# Bosnia and Herzegovina - Sarajevo
# Botswana - Gaborone
# Brazil - Brasââ lia
# British Virgin Islands - Road Town
# Brunei - Bandar Seri Begawan
# Bulgaria - Sofia
# Burkina Faso - Ouagadougou
# Burundi - Bujumbura
# Cambodia - Phnom Penh
# Cameroon - YaoundâÂ©
# Canada - Ottawa
# Cape Verde - Praia
# Cayman Islands - George Town
# Central African Republic - Bangui
# Chad - N''Djamena
# Chile - Santiago
# China - Beijing
# Christmas Island - Flying Fish Cove
# Cocos (Keeling) Islands - West Island
# Colombia - BogotâÂ°
# Comoros - Moroni
# Cook Islands - Avarua
# Costa Rica - San JosâÂ©
# Croatia - Zagreb
# Cuba - Havana
# CuraâÃao - Willemstad
# Cyprus - Nicosia
# Czech Republic - Prague
# CâÂ¥te d''Ivoire - Yamoussoukro
# Democratic Republic of the Congo - Kinshasa
# Denmark - Copenhagen
# Djibouti - Djibouti
# Dominica - Roseau
# Dominican Republic - Santo Domingo
# East Timor (Timor-Leste) - Dili
# Easter Island - Hanga Roa
# Ecuador - Quito
# Egypt - Cairo
# El Salvador - San Salvador
# Equatorial Guinea - Malabo
# Eritrea - Asmara
# Estonia - Tallinn
# Ethiopia - Addis Ababa
# Falkland Islands - Stanley
# Faroe Islands - Tââ¥rshavn
# Federated States of Micronesia - Palikir
# Fiji - Suva
# Finland - Helsinki
# France - Paris
# French Guiana - Cayenne
# French Polynesia - Papeete
# Gabon - Libreville
# Gambia - Banjul
# Georgia - Tbilisi
# Germany - Berlin
# Ghana - Accra
# Gibraltar - Gibraltar
# Greece - Athens
# Greenland - Nuuk
# Grenada - St. George''s
# Guam - Hagââ¢tâÂ±a
# Guatemala - Guatemala City
# Guernsey - St. Peter Port
# Guinea - Conakry
# Guinea-Bissau - Bissau
# Guyana - Georgetown
# Haiti - Port-au-Prince
# Honduras - Tegucigalpa
# Hungary - Budapest
# Iceland - Reykjavââ k
# India - New Delhi
# Indonesia - Jakarta
# Iran - Tehran
# Iraq - Baghdad
# Ireland - Dublin
# Isle of Man - Douglas
# Israel - Jerusalem
# Italy - Rome
# Jamaica - Kingston
# Japan - Tokyo
# Jersey - St. Helier
# Jordan - Amman
# Kazakhstan - Astana
# Kenya - Nairobi
# Kiribati - Tarawa
# Kosovo - Pristina
# Kuwait - Kuwait City
# Kyrgyzstan - Bishkek
# Laos - Vientiane
# Latvia - Riga
# Lebanon - Beirut
# Lesotho - Maseru
# Liberia - Monrovia
# Libya - Tripoli
# Liechtenstein - Vaduz
# Lithuania - Vilnius
# Luxembourg - Luxembourg
# Macedonia - Skopje
# Madagascar - Antananarivo
# Malawi - Lilongwe
# Malaysia - Kuala Lumpur
# Maldives - MalâÂ©
# Mali - Bamako
# Malta - Valletta
# Marshall Islands - Majuro
# Mauritania - Nouakchott
# Mauritius - Port Louis
# Mexico - Mexico City
# Moldova - Chisinau
# Monaco - Monaco
# Mongolia - Ulaanbaatar
# Montenegro - Podgorica
# Montserrat - Plymouth
# Morocco - Rabat
# Mozambique - Maputo
# Myanmar - Naypyidaw
# Nagorno-Karabakh Republic - Stepanakert
# Namibia - Windhoek
# Nauru - Yaren
# Nepal - Kathmandu
# Netherlands - Amsterdam
# New Caledonia - NoumâÂ©a
# New Zealand - Wellington
# Nicaragua - Managua
# Niger - Niamey
# Nigeria - Abuja
# Niue - Alofi
# Norfolk Island - Kingston
# North Korea - Pyongyang
# Northern Cyprus - Nicosia
# United Kingdom Northern Ireland - Belfast
# Northern Mariana Islands - Saipan
# Norway - Oslo
# Oman - Muscat
# Pakistan - Islamabad
# Palau - Ngerulmud
# Palestine - Jerusalem
# Panama - Panama City
# Papua New Guinea - Port Moresby
# Paraguay - Asunciââ¥n
# Peru - Lima
# Philippines - Manila
# Pitcairn Islands - Adamstown
# Poland - Warsaw
# Portugal - Lisbon
# Puerto Rico - San Juan
# Qatar - Doha
# Republic of China (Taiwan) - Taipei
# Republic of the Congo - Brazzaville
# Romania - Bucharest
# Russia - Moscow
# Rwanda - Kigali
# Saint BarthâÂ©lemy - Gustavia
# Saint Helena - Jamestown
# Saint Kitts and Nevis - Basseterre
# Saint Lucia - Castries
# Saint Martin - Marigot
# Saint Pierre and Miquelon - St. Pierre
# Saint Vincent and the Grenadines - Kingstown
# Samoa - Apia
# San Marino - San Marino
# Saudi Arabia - Riyadh
# Scotland - Edinburgh
# Senegal - Dakar
# Serbia - Belgrade
# Seychelles - Victoria
# Sierra Leone - Freetown
# Singapore - Singapore
# Sint Maarten - Philipsburg
# Slovakia - Bratislava
# Slovenia - Ljubljana
# Solomon Islands - Honiara
# Somalia - Mogadishu
# Somaliland - Hargeisa
# South Africa - Pretoria
# South Georgia and the South Sandwich Islands - Grytviken
# South Korea - Seoul
# South Ossetia - Tskhinvali
# South Sudan - Juba
# Spain - Madrid
# Sri Lanka - Sri Jayawardenapura Kotte
# Sudan - Khartoum
# Suriname - Paramaribo
# Swaziland - Mbabane
# Sweden - Stockholm
# Switzerland - Bern
# Syria - Damascus
# SâÂ£o TomâÂ© and Prââ ncipe - SâÂ£o TomâÂ©
# Tajikistan - Dushanbe
# Tanzania - Dodoma
# Thailand - Bangkok
# Togo - LomâÂ©
# Tonga - NukuÂ Âªalofa
# Transnistria - Tiraspol
# Trinidad and Tobago - Port of Spain
# Tristan da Cunha - Edinburgh of the Seven Seas
# Tunisia - Tunis
# Turkey - Ankara
# Turkmenistan - Ashgabat
# Turks and Caicos Islands - Cockburn Town
# Tuvalu - Funafuti
# Uganda - Kampala
# Ukraine - Kyiv
# United Arab Emirates - Abu Dhabi
# United Kingdom; England - London
# United States - Washington D.C.
# United States Virgin Islands - Charlotte Amalie
# Uruguay - Montevideo
# Uzbekistan - Tashkent
# Vanuatu - Port Vila
# Vatican City - Vatican City
# Venezuela - Caracas
# Vietnam - Hanoi
# Wales - Cardiff
# Wallis and Futuna - Mata-Utu
# Western Sahara - El Aaiââ«n
# Yemen - SanaâÂ°
# Zambia - Lusaka
# Zimbabwe - Harare
# 247
#                  COUNTRY              CAPITAL
# 0               Abkhazia              Sukhumi
# 1            Afghanistan                Kabul
# 2  Akrotiri and Dhekelia  Episkopi Cantonment
# 3                Albania               Tirana
# 4                Algeria              Algiers

# %%
# 한번 더 실행해보기
country_capital_data_pipeline_v2(link)
# Out:
# Abkhazia - Sukhumi
# Afghanistan - Kabul
# Akrotiri and Dhekelia - Episkopi Cantonment
# Albania - Tirana
# Algeria - Algiers
# American Samoa - Pago Pago
# Andorra - Andorra la Vella
# Angola - Luanda
# Anguilla - The Valley
# Antigua and Barbuda - St. John''s
# Argentina - Buenos Aires
# Armenia - Yerevan
# Aruba - Oranjestad
# Ascension Island - Georgetown
# Australia - Canberra
# Austria - Vienna
# Azerbaijan - Baku
# Bahamas - Nassau
# Bahrain - Manama
# Bangladesh - Dhaka
# Barbados - Bridgetown
# Belarus - Minsk
# Belgium - Brussels
# Belize - Belmopan
# Benin - Porto-Novo
# Bermuda - Hamilton
# Bhutan - Thimphu
# Bolivia - La Paz
# Bosnia and Herzegovina - Sarajevo
# Botswana - Gaborone
# Brazil - Brasââ lia
# British Virgin Islands - Road Town
# Brunei - Bandar Seri Begawan
# Bulgaria - Sofia
# Burkina Faso - Ouagadougou
# Burundi - Bujumbura
# Cambodia - Phnom Penh
# Cameroon - YaoundâÂ©
# Canada - Ottawa
# Cape Verde - Praia
# Cayman Islands - George Town
# Central African Republic - Bangui
# Chad - N''Djamena
# Chile - Santiago
# China - Beijing
# Christmas Island - Flying Fish Cove
# Cocos (Keeling) Islands - West Island
# Colombia - BogotâÂ°
# Comoros - Moroni
# Cook Islands - Avarua
# Costa Rica - San JosâÂ©
# Croatia - Zagreb
# Cuba - Havana
# CuraâÃao - Willemstad
# Cyprus - Nicosia
# Czech Republic - Prague
# CâÂ¥te d''Ivoire - Yamoussoukro
# Democratic Republic of the Congo - Kinshasa
# Denmark - Copenhagen
# Djibouti - Djibouti
# Dominica - Roseau
# Dominican Republic - Santo Domingo
# East Timor (Timor-Leste) - Dili
# Easter Island - Hanga Roa
# Ecuador - Quito
# Egypt - Cairo
# El Salvador - San Salvador
# Equatorial Guinea - Malabo
# Eritrea - Asmara
# Estonia - Tallinn
# Ethiopia - Addis Ababa
# Falkland Islands - Stanley
# Faroe Islands - Tââ¥rshavn
# Federated States of Micronesia - Palikir
# Fiji - Suva
# Finland - Helsinki
# France - Paris
# French Guiana - Cayenne
# French Polynesia - Papeete
# Gabon - Libreville
# Gambia - Banjul
# Georgia - Tbilisi
# Germany - Berlin
# Ghana - Accra
# Gibraltar - Gibraltar
# Greece - Athens
# Greenland - Nuuk
# Grenada - St. George''s
# Guam - Hagââ¢tâÂ±a
# Guatemala - Guatemala City
# Guernsey - St. Peter Port
# Guinea - Conakry
# Guinea-Bissau - Bissau
# Guyana - Georgetown
# Haiti - Port-au-Prince
# Honduras - Tegucigalpa
# Hungary - Budapest
# Iceland - Reykjavââ k
# India - New Delhi
# Indonesia - Jakarta
# Iran - Tehran
# Iraq - Baghdad
# Ireland - Dublin
# Isle of Man - Douglas
# Israel - Jerusalem
# Italy - Rome
# Jamaica - Kingston
# Japan - Tokyo
# Jersey - St. Helier
# Jordan - Amman
# Kazakhstan - Astana
# Kenya - Nairobi
# Kiribati - Tarawa
# Kosovo - Pristina
# Kuwait - Kuwait City
# Kyrgyzstan - Bishkek
# Laos - Vientiane
# Latvia - Riga
# Lebanon - Beirut
# Lesotho - Maseru
# Liberia - Monrovia
# Libya - Tripoli
# Liechtenstein - Vaduz
# Lithuania - Vilnius
# Luxembourg - Luxembourg
# Macedonia - Skopje
# Madagascar - Antananarivo
# Malawi - Lilongwe
# Malaysia - Kuala Lumpur
# Maldives - MalâÂ©
# Mali - Bamako
# Malta - Valletta
# Marshall Islands - Majuro
# Mauritania - Nouakchott
# Mauritius - Port Louis
# Mexico - Mexico City
# Moldova - Chisinau
# Monaco - Monaco
# Mongolia - Ulaanbaatar
# Montenegro - Podgorica
# Montserrat - Plymouth
# Morocco - Rabat
# Mozambique - Maputo
# Myanmar - Naypyidaw
# Nagorno-Karabakh Republic - Stepanakert
# Namibia - Windhoek
# Nauru - Yaren
# Nepal - Kathmandu
# Netherlands - Amsterdam
# New Caledonia - NoumâÂ©a
# New Zealand - Wellington
# Nicaragua - Managua
# Niger - Niamey
# Nigeria - Abuja
# Niue - Alofi
# Norfolk Island - Kingston
# North Korea - Pyongyang
# Northern Cyprus - Nicosia
# United Kingdom Northern Ireland - Belfast
# Northern Mariana Islands - Saipan
# Norway - Oslo
# Oman - Muscat
# Pakistan - Islamabad
# Palau - Ngerulmud
# Palestine - Jerusalem
# Panama - Panama City
# Papua New Guinea - Port Moresby
# Paraguay - Asunciââ¥n
# Peru - Lima
# Philippines - Manila
# Pitcairn Islands - Adamstown
# Poland - Warsaw
# Portugal - Lisbon
# Puerto Rico - San Juan
# Qatar - Doha
# Republic of China (Taiwan) - Taipei
# Republic of the Congo - Brazzaville
# Romania - Bucharest
# Russia - Moscow
# Rwanda - Kigali
# Saint BarthâÂ©lemy - Gustavia
# Saint Helena - Jamestown
# Saint Kitts and Nevis - Basseterre
# Saint Lucia - Castries
# Saint Martin - Marigot
# Saint Pierre and Miquelon - St. Pierre
# Saint Vincent and the Grenadines - Kingstown
# Samoa - Apia
# San Marino - San Marino
# Saudi Arabia - Riyadh
# Scotland - Edinburgh
# Senegal - Dakar
# Serbia - Belgrade
# Seychelles - Victoria
# Sierra Leone - Freetown
# Singapore - Singapore
# Sint Maarten - Philipsburg
# Slovakia - Bratislava
# Slovenia - Ljubljana
# Solomon Islands - Honiara
# Somalia - Mogadishu
# Somaliland - Hargeisa
# South Africa - Pretoria
# South Georgia and the South Sandwich Islands - Grytviken
# South Korea - Seoul
# South Ossetia - Tskhinvali
# South Sudan - Juba
# Spain - Madrid
# Sri Lanka - Sri Jayawardenapura Kotte
# Sudan - Khartoum
# Suriname - Paramaribo
# Swaziland - Mbabane
# Sweden - Stockholm
# Switzerland - Bern
# Syria - Damascus
# SâÂ£o TomâÂ© and Prââ ncipe - SâÂ£o TomâÂ©
# Tajikistan - Dushanbe
# Tanzania - Dodoma
# Thailand - Bangkok
# Togo - LomâÂ©
# Tonga - NukuÂ Âªalofa
# Transnistria - Tiraspol
# Trinidad and Tobago - Port of Spain
# Tristan da Cunha - Edinburgh of the Seven Seas
# Tunisia - Tunis
# Turkey - Ankara
# Turkmenistan - Ashgabat
# Turks and Caicos Islands - Cockburn Town
# Tuvalu - Funafuti
# Uganda - Kampala
# Ukraine - Kyiv
# United Arab Emirates - Abu Dhabi
# United Kingdom; England - London
# United States - Washington D.C.
# United States Virgin Islands - Charlotte Amalie
# Uruguay - Montevideo
# Uzbekistan - Tashkent
# Vanuatu - Port Vila
# Vatican City - Vatican City
# Venezuela - Caracas
# Vietnam - Hanoi
# Wales - Cardiff
# Wallis and Futuna - Mata-Utu
# Western Sahara - El Aaiââ«n
# Yemen - SanaâÂ°
# Zambia - Lusaka
# Zimbabwe - Harare
# 247
#                  COUNTRY              CAPITAL
# 0               Abkhazia              Sukhumi
# 1            Afghanistan                Kabul
# 2  Akrotiri and Dhekelia  Episkopi Cantonment
# 3                Albania               Tirana
# 4                Algeria              Algiers

# %% [markdown]
# ## 혹시라도 문제가 생겼을 때 문제를 확인할 수 있도록 에러를 처리하더라도 알 수 있도록 처리가 필요함

# %%
# 이번에는 Transaction이 제대로 동작하는지 load_v3를 만들고 고의로 SQL 문법 에러를 내보기
def load_v3(con, records):
    target_table = "dev.raw_data.country_capital"
    try:
        con.execute("BEGIN;")
        # 여기서 CREATE OR REPLACE TABLE이 사용되면 안됨. DDL이라 Snowflake에서는 transaction을 지키지 않기 때문
        con.execute(f"CREATE TABLE IF NOT EXISTS {target_table} (country varchar primary key, capital varchar);")
        con.execute(f"DELETE FROM {target_table};")
        for r in records:
            country = r[0].replace("'", "''")
            capital = r[1].replace("'", "''")
            print(country, "-", capital)

            # 아래 고의로 에러를 냈음
            sql = f"INSERT INTTO {target_table} (country, capital) VALUES ('{country}', '{capital}')"
            con.execute(sql)
        con.execute("COMMIT;")
    except Exception as e:
        con.execute("ROLLBACK;")
        print(e)
        raise e

# %%
load_v3(cur, lines)
# Out:
# country - capital
# 001003 (42000): SQL compilation error:
# syntax error line 1 at position 7 unexpected 'INTTO'.
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 load_v3(cur, lines)
#
# Cell In[22], line 21, in load_v3(con, records)
#      19 con.execute("ROLLBACK;")
#      20 print(e)
# ---> 21 raise e
#
# Cell In[22], line 16, in load_v3(con, records)
#      14         # 아래 고의로 에러를 냈음
#      15         sql = f"INSERT INTTO {target_table} (country, capital) VALUES ('{country}', '{capital}')"
# ---> 16         con.execute(sql)
#      17     con.execute("COMMIT;")
#      18 except Exception as e:
#
# File ~/Desktop/data pipeline/.venv/lib/python3.11/site-packages/snowflake/connector/cursor.py:1121, in SnowflakeCursorBase.execute(self, command, params, _bind_stage, timeout, _exec_async, _no_retry, _do_reset, _put_callback, _put_azure_callback, _put_callback_output_stream, _get_callback, _get_azure_callback, _get_callback_output_stream, _show_progress_bar, _statement_params, _is_internal, _describe_only, _no_results, _is_put_get, _raise_put_get_error, _force_put_overwrite, _skip_upload_on_content_match, file_stream, num_statements, _force_qmark_paramstyle, _dataframe_ast)
#    1117     is_integrity_error = (
#    1118         code == "100072"
#    1119     )  # NULL result in a non-nullable column
#    1120     error_class = IntegrityError if is_integrity_error else ProgrammingError
# -> 1121     Error.errorhandler_wrapper(self.connection, self, error_class, errvalue)
#    1122 return self
#
# File ~/Desktop/data pipeline/.venv/lib/python3.11/site-packages/snowflake/connector/errors.py:286, in Error.errorhandler_wrapper(connection, cursor, error_class, error_value)
#     263 @staticmethod
#     264 def errorhandler_wrapper(
#     265     connection: SnowflakeConnection | None,
#    (...)    268     error_value: dict[str, Any],
#     269 ) -> None:
#     270     """Error handler wrapper that calls the errorhandler method.
#     271
#     272     Args:
#    (...)    283         exception to the first handler in that order.
#     284     """
# --> 286     handed_over = Error.hand_to_other_handler(
#     287         connection,
#     288         cursor,
#     289         error_class,
#     290         error_value,
#     291     )
#     292     if not handed_over:
#     293         raise Error.errorhandler_make_exception(
#     294             error_class,
#     295             error_value,
#     296         )
#
# File ~/Desktop/data pipeline/.venv/lib/python3.11/site-packages/snowflake/connector/errors.py:341, in Error.hand_to_other_handler(connection, cursor, error_class, error_value)
#     339 if cursor is not None:
#     340     cursor.messages.append((error_class, error_value))
# --> 341     cursor.errorhandler(connection, cursor, error_class, error_value)
#     342     return True
#     343 elif connection is not None:
#
# File ~/Desktop/data pipeline/.venv/lib/python3.11/site-packages/snowflake/connector/errors.py:217, in Error.default_errorhandler(connection, cursor, error_class, error_value)
#     215 errno = error_value.get("errno")
#     216 done_format_msg = error_value.get("done_format_msg")
# --> 217 raise error_class(
#     218     msg=error_value.get("msg"),
#     219     errno=None if errno is None else int(errno),
#     220     sqlstate=error_value.get("sqlstate"),
#     221     sfqid=error_value.get("sfqid"),
#     222     query=error_value.get("query"),
#     223     done_format_msg=(
#     224         None if done_format_msg is None else bool(done_format_msg)
#     225     ),
#     226     connection=connection,
#     227     cursor=cursor,
#     228 )
#
# ProgrammingError: 001003 (42000): SQL compilation error:
# syntax error line 1 at position 7 unexpected 'INTTO'.

# %%
# transaction이 동작하지 않았다면 앞서 DELETE가 실행되어서 테이블의 내용이 없어야함.
# 248개의 레코드가 있음을 확인해보자
cur.execute("SELECT COUNT(1) FROM dev.raw_data.country_capital")
results = cur.fetchone()
print(results)
# Out:
# (247,)
